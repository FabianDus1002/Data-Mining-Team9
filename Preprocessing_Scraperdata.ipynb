# %%
import pandas as pd
import os
import logging

logging.basicConfig(filename='log.log', level=logging.INFO)

# %%
base_url = r"./data_original/"
dest_url = r"./data_cleaned/"
files = []
for file in os.listdir(base_url):
    if file.endswith(".csv"):
        files.append(file)

print(files)
# Out:
# ['1001-3000 study reports.csv', '101-1000 study reports.csv', '3 berichte in den 5000er bereichen study reports.csv', '3001-4170 study reports.csv', '4172-4405 study reports.csv', '4407-4637 study reports.csv', '4639-4937 study reports.csv', '5380 - ende 7424 normale version reichen study reports.csv', 'first 100 study reports.csv', 'short version study reports.csv', 'short version study reports_copy.csv']

# %% [markdown]
# #### Preprocessing and structuring of each sub-dataset

# %%
#Some entries have another format regarding their metainformation.
#There is another column that wasnt handeled by the crawler,
#therefore some entries have a right shift of the values "Studiengang" and "Fakultaet".
#To correct this, there is the function correct_right_shift().
#However, the "Verfasser-ID" wasnt scraped in these cases but its a neglectable value and is therefore not corrected.

def correct_right_shift(df):
    for index, row in df.iterrows():
        try:
            if(row["Verfasser-ID"].isnumeric()) is not True:
                copy_studiengang = row["Verfasser-ID"]
                copy_fakultaet = row["Studiengang"]
                df.loc[index, "Studiengang"] = copy_studiengang
                df.loc[index, "Fakultaet"] = copy_fakultaet
                df.loc[index, "Verfasser-ID"] = "NO AUTHOR ID FROM SCRAPER"
        except AttributeError:
            print("Attribute Error in: " + str(index) + " Column is already a number")

# %%
# Some entries have another format regarding their main information.
# The columns "Budget" and "Finanzierung" arent there and therefore need to be added as a empty column to ensure alignment

def add_budget_and_finance_column(df):
    if ("Budget" not in df.columns):
        df["Budget"] = "NO BUDGET COLUMN IN REPORT"
    if ("Finanzierung" not in df.columns):
        df["Finanzierung"] = "NO FINANCE COLUMN IN REPORT"

# %%
# The crawler added an index column, however, since all files need to be concatenated, we need an overall index.
# Therefore the index from each file needs to be removed

def drop_index_column(df):
    df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
for file in files:
    print(file)
    url = base_url + file
    df = pd.read_csv(url, sep=";")
    correct_right_shift(df)
    add_budget_and_finance_column(df)
    drop_index_column(df)
    df.to_csv(dest_url + file, sep=";", index=False)
# Out:
# 1001-3000 study reports.csv
# 101-1000 study reports.csv
# 3 berichte in den 5000er bereichen study reports.csv
# 3001-4170 study reports.csv
# Attribute Error in: 0 Column is already a number
# Attribute Error in: 1 Column is already a number
# Attribute Error in: 2 Column is already a number
# Attribute Error in: 3 Column is already a number
# Attribute Error in: 4 Column is already a number
# Attribute Error in: 5 Column is already a number
# Attribute Error in: 6 Column is already a number
# Attribute Error in: 7 Column is already a number
# Attribute Error in: 8 Column is already a number
# Attribute Error in: 9 Column is already a number
# Attribute Error in: 10 Column is already a number
# Attribute Error in: 11 Column is already a number
# Attribute Error in: 12 Column is already a number
# Attribute Error in: 13 Column is already a number
# Attribute Error in: 14 Column is already a number
# Attribute Error in: 15 Column is already a number
# Attribute Error in: 16 Column is already a number
# Attribute Error in: 17 Column is already a number
# Attribute Error in: 18 Column is already a number
# Attribute Error in: 19 Column is already a number
# Attribute Error in: 20 Column is already a number
# Attribute Error in: 21 Column is already a number
# Attribute Error in: 22 Column is already a number
# Attribute Error in: 23 Column is already a number
# Attribute Error in: 24 Column is already a number
# Attribute Error in: 25 Column is already a number
# Attribute Error in: 26 Column is already a number
# Attribute Error in: 27 Column is already a number
# Attribute Error in: 28 Column is already a number
# Attribute Error in: 29 Column is already a number
# Attribute Error in: 30 Column is already a number
# Attribute Error in: 31 Column is already a number
# Attribute Error in: 32 Column is already a number
# Attribute Error in: 33 Column is already a number
# Attribute Error in: 34 Column is already a number
# Attribute Error in: 35 Column is already a number
# Attribute Error in: 36 Column is already a number
# Attribute Error in: 37 Column is already a number
# Attribute Error in: 38 Column is already a number
# Attribute Error in: 39 Column is already a number
# Attribute Error in: 40 Column is already a number
# Attribute Error in: 41 Column is already a number
# Attribute Error in: 42 Column is already a number
# Attribute Error in: 43 Column is already a number
# Attribute Error in: 44 Column is already a number
# Attribute Error in: 45 Column is already a number
# Attribute Error in: 46 Column is already a number
# Attribute Error in: 47 Column is already a number
# Attribute Error in: 48 Column is already a number
# Attribute Error in: 49 Column is already a number
# Attribute Error in: 50 Column is already a number
# Attribute Error in: 51 Column is already a number
# Attribute Error in: 52 Column is already a number
# Attribute Error in: 53 Column is already a number
# Attribute Error in: 54 Column is already a number
# Attribute Error in: 55 Column is already a number
# Attribute Error in: 56 Column is already a number
# Attribute Error in: 57 Column is already a number
# Attribute Error in: 58 Column is already a number
# Attribute Error in: 59 Column is already a number
# Attribute Error in: 60 Column is already a number
# Attribute Error in: 61 Column is already a number
# Attribute Error in: 62 Column is already a number
# Attribute Error in: 63 Column is already a number
# Attribute Error in: 64 Column is already a number
# Attribute Error in: 65 Column is already a number
# Attribute Error in: 66 Column is already a number
# Attribute Error in: 67 Column is already a number
# Attribute Error in: 68 Column is already a number
# Attribute Error in: 69 Column is already a number
# Attribute Error in: 70 Column is already a number
# Attribute Error in: 71 Column is already a number
# Attribute Error in: 72 Column is already a number
# Attribute Error in: 73 Column is already a number
# Attribute Error in: 74 Column is already a number
# Attribute Error in: 75 Column is already a number
# Attribute Error in: 76 Column is already a number
# Attribute Error in: 77 Column is already a number
# Attribute Error in: 78 Column is already a number
# Attribute Error in: 79 Column is already a number
# Attribute Error in: 80 Column is already a number
# Attribute Error in: 81 Column is already a number
# Attribute Error in: 82 Column is already a number
# Attribute Error in: 83 Column is already a number
# Attribute Error in: 84 Column is already a number
# Attribute Error in: 85 Column is already a number
# Attribute Error in: 86 Column is already a number
# Attribute Error in: 87 Column is already a number
# Attribute Error in: 88 Column is already a number
# Attribute Error in: 89 Column is already a number
# Attribute Error in: 90 Column is already a number
# Attribute Error in: 91 Column is already a number
# Attribute Error in: 92 Column is already a number
# Attribute Error in: 93 Column is already a number
# Attribute Error in: 94 Column is already a number
# Attribute Error in: 95 Column is already a number
# Attribute Error in: 96 Column is already a number
# Attribute Error in: 97 Column is already a number
# Attribute Error in: 98 Column is already a number
# Attribute Error in: 99 Column is already a number
# Attribute Error in: 100 Column is already a number
# Attribute Error in: 101 Column is already a number
# Attribute Error in: 102 Column is already a number
# Attribute Error in: 103 Column is already a number
# Attribute Error in: 104 Column is already a number
# Attribute Error in: 105 Column is already a number
# Attribute Error in: 106 Column is already a number
# Attribute Error in: 107 Column is already a number
# Attribute Error in: 108 Column is already a number
# Attribute Error in: 109 Column is already a number
# Attribute Error in: 110 Column is already a number
# Attribute Error in: 111 Column is already a number
# Attribute Error in: 112 Column is already a number
# Attribute Error in: 113 Column is already a number
# Attribute Error in: 114 Column is already a number
# Attribute Error in: 115 Column is already a number
# Attribute Error in: 116 Column is already a number
# Attribute Error in: 117 Column is already a number
# Attribute Error in: 118 Column is already a number
# Attribute Error in: 119 Column is already a number
# Attribute Error in: 120 Column is already a number
# Attribute Error in: 121 Column is already a number
# Attribute Error in: 122 Column is already a number
# Attribute Error in: 123 Column is already a number
# Attribute Error in: 124 Column is already a number
# Attribute Error in: 125 Column is already a number
# Attribute Error in: 126 Column is already a number
# Attribute Error in: 127 Column is already a number
# Attribute Error in: 128 Column is already a number
# Attribute Error in: 129 Column is already a number
# Attribute Error in: 130 Column is already a number
# Attribute Error in: 131 Column is already a number
# Attribute Error in: 132 Column is already a number
# Attribute Error in: 133 Column is already a number
# Attribute Error in: 134 Column is already a number
# Attribute Error in: 135 Column is already a number
# Attribute Error in: 136 Column is already a number
# Attribute Error in: 137 Column is already a number
# Attribute Error in: 138 Column is already a number
# Attribute Error in: 139 Column is already a number
# Attribute Error in: 140 Column is already a number
# Attribute Error in: 141 Column is already a number
# Attribute Error in: 142 Column is already a number
# Attribute Error in: 143 Column is already a number
# Attribute Error in: 144 Column is already a number
# Attribute Error in: 145 Column is already a number
# Attribute Error in: 146 Column is already a number
# Attribute Error in: 147 Column is already a number
# Attribute Error in: 148 Column is already a number
# Attribute Error in: 149 Column is already a number
# Attribute Error in: 150 Column is already a number
# Attribute Error in: 151 Column is already a number
# Attribute Error in: 152 Column is already a number
# Attribute Error in: 153 Column is already a number
# Attribute Error in: 154 Column is already a number
# Attribute Error in: 155 Column is already a number
# Attribute Error in: 156 Column is already a number
# Attribute Error in: 157 Column is already a number
# Attribute Error in: 158 Column is already a number
# Attribute Error in: 159 Column is already a number
# Attribute Error in: 160 Column is already a number
# Attribute Error in: 161 Column is already a number
# Attribute Error in: 162 Column is already a number
# Attribute Error in: 163 Column is already a number
# Attribute Error in: 164 Column is already a number
# Attribute Error in: 165 Column is already a number
# Attribute Error in: 166 Column is already a number
# Attribute Error in: 167 Column is already a number
# Attribute Error in: 168 Column is already a number
# Attribute Error in: 169 Column is already a number
# Attribute Error in: 170 Column is already a number
# Attribute Error in: 171 Column is already a number
# Attribute Error in: 172 Column is already a number
# Attribute Error in: 173 Column is already a number
# Attribute Error in: 174 Column is already a number
# Attribute Error in: 175 Column is already a number
# Attribute Error in: 176 Column is already a number
# Attribute Error in: 177 Column is already a number
# Attribute Error in: 178 Column is already a number
# Attribute Error in: 179 Column is already a number
# Attribute Error in: 180 Column is already a number
# Attribute Error in: 181 Column is already a number
# Attribute Error in: 182 Column is already a number
# Attribute Error in: 183 Column is already a number
# Attribute Error in: 184 Column is already a number
# Attribute Error in: 185 Column is already a number
# Attribute Error in: 186 Column is already a number
# Attribute Error in: 187 Column is already a number
# Attribute Error in: 188 Column is already a number
# Attribute Error in: 189 Column is already a number
# Attribute Error in: 190 Column is already a number
# Attribute Error in: 191 Column is already a number
# Attribute Error in: 192 Column is already a number
# Attribute Error in: 193 Column is already a number
# Attribute Error in: 194 Column is already a number
# Attribute Error in: 195 Column is already a number
# Attribute Error in: 196 Column is already a number
# Attribute Error in: 197 Column is already a number
# Attribute Error in: 198 Column is already a number
# Attribute Error in: 199 Column is already a number
# Attribute Error in: 200 Column is already a number
# Attribute Error in: 201 Column is already a number
# Attribute Error in: 202 Column is already a number
# Attribute Error in: 203 Column is already a number
# Attribute Error in: 204 Column is already a number
# Attribute Error in: 205 Column is already a number
# Attribute Error in: 206 Column is already a number
# Attribute Error in: 207 Column is already a number
# Attribute Error in: 208 Column is already a number
# Attribute Error in: 209 Column is already a number
# Attribute Error in: 210 Column is already a number
# Attribute Error in: 211 Column is already a number
# Attribute Error in: 212 Column is already a number
# Attribute Error in: 213 Column is already a number
# Attribute Error in: 214 Column is already a number
# Attribute Error in: 215 Column is already a number
# Attribute Error in: 216 Column is already a number
# Attribute Error in: 217 Column is already a number
# Attribute Error in: 218 Column is already a number
# Attribute Error in: 219 Column is already a number
# Attribute Error in: 220 Column is already a number
# Attribute Error in: 221 Column is already a number
# Attribute Error in: 222 Column is already a number
# Attribute Error in: 223 Column is already a number
# Attribute Error in: 224 Column is already a number
# Attribute Error in: 225 Column is already a number
# Attribute Error in: 226 Column is already a number
# Attribute Error in: 227 Column is already a number
# Attribute Error in: 228 Column is already a number
# Attribute Error in: 229 Column is already a number
# Attribute Error in: 230 Column is already a number
# Attribute Error in: 231 Column is already a number
# Attribute Error in: 232 Column is already a number
# Attribute Error in: 233 Column is already a number
# Attribute Error in: 234 Column is already a number
# Attribute Error in: 235 Column is already a number
# Attribute Error in: 236 Column is already a number
# Attribute Error in: 237 Column is already a number
# Attribute Error in: 238 Column is already a number
# Attribute Error in: 239 Column is already a number
# Attribute Error in: 240 Column is already a number
# Attribute Error in: 241 Column is already a number
# Attribute Error in: 242 Column is already a number
# Attribute Error in: 243 Column is already a number
# Attribute Error in: 244 Column is already a number
# Attribute Error in: 245 Column is already a number
# Attribute Error in: 246 Column is already a number
# Attribute Error in: 247 Column is already a number
# Attribute Error in: 248 Column is already a number
# Attribute Error in: 249 Column is already a number
# Attribute Error in: 250 Column is already a number
# Attribute Error in: 251 Column is already a number
# Attribute Error in: 252 Column is already a number
# Attribute Error in: 253 Column is already a number
# Attribute Error in: 254 Column is already a number
# Attribute Error in: 255 Column is already a number
# Attribute Error in: 256 Column is already a number
# Attribute Error in: 257 Column is already a number
# Attribute Error in: 258 Column is already a number
# Attribute Error in: 259 Column is already a number
# Attribute Error in: 260 Column is already a number
# Attribute Error in: 261 Column is already a number
# Attribute Error in: 262 Column is already a number
# Attribute Error in: 263 Column is already a number
# Attribute Error in: 264 Column is already a number
# Attribute Error in: 265 Column is already a number
# Attribute Error in: 266 Column is already a number
# Attribute Error in: 267 Column is already a number
# Attribute Error in: 268 Column is already a number
# Attribute Error in: 269 Column is already a number
# Attribute Error in: 270 Column is already a number
# Attribute Error in: 271 Column is already a number
# Attribute Error in: 272 Column is already a number
# Attribute Error in: 273 Column is already a number
# Attribute Error in: 274 Column is already a number
# Attribute Error in: 275 Column is already a number
# Attribute Error in: 276 Column is already a number
# Attribute Error in: 277 Column is already a number
# Attribute Error in: 278 Column is already a number
# Attribute Error in: 279 Column is already a number
# Attribute Error in: 280 Column is already a number
# Attribute Error in: 281 Column is already a number
# Attribute Error in: 282 Column is already a number
# Attribute Error in: 283 Column is already a number
# Attribute Error in: 284 Column is already a number
# Attribute Error in: 285 Column is already a number
# Attribute Error in: 286 Column is already a number
# Attribute Error in: 287 Column is already a number
# Attribute Error in: 288 Column is already a number
# Attribute Error in: 289 Column is already a number
# Attribute Error in: 290 Column is already a number
# Attribute Error in: 291 Column is already a number
# Attribute Error in: 292 Column is already a number
# Attribute Error in: 293 Column is already a number
# Attribute Error in: 294 Column is already a number
# Attribute Error in: 295 Column is already a number
# Attribute Error in: 296 Column is already a number
# Attribute Error in: 297 Column is already a number
# Attribute Error in: 298 Column is already a number
# Attribute Error in: 299 Column is already a number
# Attribute Error in: 300 Column is already a number
# Attribute Error in: 301 Column is already a number
# Attribute Error in: 302 Column is already a number
# Attribute Error in: 303 Column is already a number
# Attribute Error in: 304 Column is already a number
# Attribute Error in: 305 Column is already a number
# Attribute Error in: 306 Column is already a number
# Attribute Error in: 307 Column is already a number
# Attribute Error in: 308 Column is already a number
# Attribute Error in: 309 Column is already a number
# Attribute Error in: 310 Column is already a number
# Attribute Error in: 311 Column is already a number
# Attribute Error in: 312 Column is already a number
# Attribute Error in: 313 Column is already a number
# Attribute Error in: 314 Column is already a number
# Attribute Error in: 315 Column is already a number
# Attribute Error in: 316 Column is already a number
# Attribute Error in: 317 Column is already a number
# Attribute Error in: 318 Column is already a number
# Attribute Error in: 319 Column is already a number
# Attribute Error in: 320 Column is already a number
# Attribute Error in: 321 Column is already a number
# Attribute Error in: 322 Column is already a number
# Attribute Error in: 323 Column is already a number
# Attribute Error in: 324 Column is already a number
# Attribute Error in: 325 Column is already a number
# Attribute Error in: 326 Column is already a number
# Attribute Error in: 327 Column is already a number
# Attribute Error in: 328 Column is already a number
# Attribute Error in: 329 Column is already a number
# Attribute Error in: 330 Column is already a number
# Attribute Error in: 331 Column is already a number
# Attribute Error in: 332 Column is already a number
# Attribute Error in: 333 Column is already a number
# Attribute Error in: 334 Column is already a number
# Attribute Error in: 335 Column is already a number
# Attribute Error in: 336 Column is already a number
# Attribute Error in: 337 Column is already a number
# Attribute Error in: 338 Column is already a number
# Attribute Error in: 339 Column is already a number
# Attribute Error in: 340 Column is already a number
# Attribute Error in: 341 Column is already a number
# Attribute Error in: 342 Column is already a number
# Attribute Error in: 343 Column is already a number
# Attribute Error in: 344 Column is already a number
# Attribute Error in: 345 Column is already a number
# Attribute Error in: 346 Column is already a number
# Attribute Error in: 347 Column is already a number
# Attribute Error in: 348 Column is already a number
# Attribute Error in: 349 Column is already a number
# Attribute Error in: 350 Column is already a number
# Attribute Error in: 351 Column is already a number
# Attribute Error in: 352 Column is already a number
# Attribute Error in: 353 Column is already a number
# Attribute Error in: 354 Column is already a number
# Attribute Error in: 355 Column is already a number
# Attribute Error in: 356 Column is already a number
# Attribute Error in: 357 Column is already a number
# Attribute Error in: 358 Column is already a number
# Attribute Error in: 359 Column is already a number
# Attribute Error in: 360 Column is already a number
# Attribute Error in: 361 Column is already a number
# Attribute Error in: 362 Column is already a number
# Attribute Error in: 363 Column is already a number
# Attribute Error in: 364 Column is already a number
# Attribute Error in: 365 Column is already a number
# Attribute Error in: 366 Column is already a number
# Attribute Error in: 367 Column is already a number
# Attribute Error in: 368 Column is already a number
# Attribute Error in: 369 Column is already a number
# Attribute Error in: 370 Column is already a number
# Attribute Error in: 371 Column is already a number
# Attribute Error in: 372 Column is already a number
# Attribute Error in: 373 Column is already a number
# Attribute Error in: 374 Column is already a number
# Attribute Error in: 375 Column is already a number
# Attribute Error in: 376 Column is already a number
# Attribute Error in: 377 Column is already a number
# Attribute Error in: 378 Column is already a number
# Attribute Error in: 379 Column is already a number
# Attribute Error in: 380 Column is already a number
# Attribute Error in: 381 Column is already a number
# Attribute Error in: 382 Column is already a number
# Attribute Error in: 383 Column is already a number
# Attribute Error in: 384 Column is already a number
# Attribute Error in: 385 Column is already a number
# Attribute Error in: 386 Column is already a number
# Attribute Error in: 387 Column is already a number
# Attribute Error in: 388 Column is already a number
# Attribute Error in: 389 Column is already a number
# Attribute Error in: 390 Column is already a number
# Attribute Error in: 391 Column is already a number
# Attribute Error in: 392 Column is already a number
# Attribute Error in: 393 Column is already a number
# Attribute Error in: 394 Column is already a number
# Attribute Error in: 395 Column is already a number
# Attribute Error in: 396 Column is already a number
# Attribute Error in: 397 Column is already a number
# Attribute Error in: 398 Column is already a number
# Attribute Error in: 399 Column is already a number
# Attribute Error in: 400 Column is already a number
# Attribute Error in: 401 Column is already a number
# Attribute Error in: 402 Column is already a number
# Attribute Error in: 403 Column is already a number
# Attribute Error in: 404 Column is already a number
# Attribute Error in: 405 Column is already a number
# Attribute Error in: 406 Column is already a number
# Attribute Error in: 407 Column is already a number
# Attribute Error in: 408 Column is already a number
# Attribute Error in: 409 Column is already a number
# Attribute Error in: 410 Column is already a number
# Attribute Error in: 411 Column is already a number
# Attribute Error in: 412 Column is already a number
# Attribute Error in: 413 Column is already a number
# Attribute Error in: 414 Column is already a number
# Attribute Error in: 415 Column is already a number
# Attribute Error in: 416 Column is already a number
# Attribute Error in: 417 Column is already a number
# Attribute Error in: 418 Column is already a number
# Attribute Error in: 419 Column is already a number
# Attribute Error in: 420 Column is already a number
# Attribute Error in: 421 Column is already a number
# Attribute Error in: 422 Column is already a number
# Attribute Error in: 423 Column is already a number
# Attribute Error in: 424 Column is already a number
# Attribute Error in: 425 Column is already a number
# Attribute Error in: 426 Column is already a number
# Attribute Error in: 427 Column is already a number
# Attribute Error in: 428 Column is already a number
# Attribute Error in: 429 Column is already a number
# Attribute Error in: 430 Column is already a number
# Attribute Error in: 431 Column is already a number
# Attribute Error in: 432 Column is already a number
# Attribute Error in: 433 Column is already a number
# Attribute Error in: 434 Column is already a number
# Attribute Error in: 435 Column is already a number
# Attribute Error in: 436 Column is already a number
# Attribute Error in: 437 Column is already a number
# Attribute Error in: 438 Column is already a number
# Attribute Error in: 439 Column is already a number
# Attribute Error in: 440 Column is already a number
# Attribute Error in: 441 Column is already a number
# Attribute Error in: 442 Column is already a number
# Attribute Error in: 443 Column is already a number
# Attribute Error in: 444 Column is already a number
# Attribute Error in: 445 Column is already a number
# Attribute Error in: 446 Column is already a number
# Attribute Error in: 447 Column is already a number
# Attribute Error in: 448 Column is already a number
# Attribute Error in: 449 Column is already a number
# Attribute Error in: 450 Column is already a number
# Attribute Error in: 451 Column is already a number
# Attribute Error in: 452 Column is already a number
# Attribute Error in: 453 Column is already a number
# Attribute Error in: 454 Column is already a number
# Attribute Error in: 455 Column is already a number
# Attribute Error in: 456 Column is already a number
# Attribute Error in: 457 Column is already a number
# Attribute Error in: 458 Column is already a number
# Attribute Error in: 459 Column is already a number
# Attribute Error in: 460 Column is already a number
# Attribute Error in: 461 Column is already a number
# Attribute Error in: 462 Column is already a number
# Attribute Error in: 463 Column is already a number
# Attribute Error in: 464 Column is already a number
# Attribute Error in: 465 Column is already a number
# Attribute Error in: 466 Column is already a number
# Attribute Error in: 467 Column is already a number
# Attribute Error in: 468 Column is already a number
# Attribute Error in: 469 Column is already a number
# Attribute Error in: 470 Column is already a number
# Attribute Error in: 471 Column is already a number
# Attribute Error in: 472 Column is already a number
# Attribute Error in: 473 Column is already a number
# Attribute Error in: 474 Column is already a number
# Attribute Error in: 475 Column is already a number
# Attribute Error in: 476 Column is already a number
# Attribute Error in: 477 Column is already a number
# Attribute Error in: 478 Column is already a number
# Attribute Error in: 479 Column is already a number
# Attribute Error in: 480 Column is already a number
# Attribute Error in: 481 Column is already a number
# Attribute Error in: 482 Column is already a number
# Attribute Error in: 483 Column is already a number
# Attribute Error in: 484 Column is already a number
# Attribute Error in: 485 Column is already a number
# Attribute Error in: 486 Column is already a number
# Attribute Error in: 487 Column is already a number
# Attribute Error in: 488 Column is already a number
# Attribute Error in: 489 Column is already a number
# Attribute Error in: 490 Column is already a number
# Attribute Error in: 491 Column is already a number
# Attribute Error in: 492 Column is already a number
# Attribute Error in: 493 Column is already a number
# Attribute Error in: 494 Column is already a number
# Attribute Error in: 495 Column is already a number
# Attribute Error in: 496 Column is already a number
# Attribute Error in: 497 Column is already a number
# Attribute Error in: 498 Column is already a number
# Attribute Error in: 499 Column is already a number
# Attribute Error in: 500 Column is already a number
# Attribute Error in: 501 Column is already a number
# Attribute Error in: 502 Column is already a number
# Attribute Error in: 503 Column is already a number
# Attribute Error in: 504 Column is already a number
# Attribute Error in: 505 Column is already a number
# Attribute Error in: 506 Column is already a number
# Attribute Error in: 507 Column is already a number
# Attribute Error in: 508 Column is already a number
# Attribute Error in: 509 Column is already a number
# Attribute Error in: 510 Column is already a number
# Attribute Error in: 511 Column is already a number
# Attribute Error in: 512 Column is already a number
# Attribute Error in: 513 Column is already a number
# Attribute Error in: 514 Column is already a number
# Attribute Error in: 515 Column is already a number
# Attribute Error in: 516 Column is already a number
# Attribute Error in: 517 Column is already a number
# Attribute Error in: 518 Column is already a number
# Attribute Error in: 519 Column is already a number
# Attribute Error in: 520 Column is already a number
# Attribute Error in: 521 Column is already a number
# Attribute Error in: 522 Column is already a number
# Attribute Error in: 523 Column is already a number
# Attribute Error in: 524 Column is already a number
# Attribute Error in: 525 Column is already a number
# Attribute Error in: 526 Column is already a number
# Attribute Error in: 527 Column is already a number
# Attribute Error in: 528 Column is already a number
# Attribute Error in: 529 Column is already a number
# Attribute Error in: 530 Column is already a number
# Attribute Error in: 531 Column is already a number
# Attribute Error in: 532 Column is already a number
# Attribute Error in: 533 Column is already a number
# Attribute Error in: 534 Column is already a number
# Attribute Error in: 535 Column is already a number
# Attribute Error in: 536 Column is already a number
# Attribute Error in: 537 Column is already a number
# Attribute Error in: 538 Column is already a number
# Attribute Error in: 539 Column is already a number
# Attribute Error in: 540 Column is already a number
# Attribute Error in: 541 Column is already a number
# Attribute Error in: 542 Column is already a number
# Attribute Error in: 543 Column is already a number
# Attribute Error in: 544 Column is already a number
# Attribute Error in: 545 Column is already a number
# Attribute Error in: 546 Column is already a number
# Attribute Error in: 547 Column is already a number
# Attribute Error in: 548 Column is already a number
# Attribute Error in: 549 Column is already a number
# Attribute Error in: 550 Column is already a number
# Attribute Error in: 551 Column is already a number
# Attribute Error in: 552 Column is already a number
# Attribute Error in: 553 Column is already a number
# Attribute Error in: 554 Column is already a number
# Attribute Error in: 555 Column is already a number
# Attribute Error in: 556 Column is already a number
# Attribute Error in: 557 Column is already a number
# Attribute Error in: 558 Column is already a number
# Attribute Error in: 559 Column is already a number
# Attribute Error in: 560 Column is already a number
# Attribute Error in: 561 Column is already a number
# Attribute Error in: 562 Column is already a number
# Attribute Error in: 563 Column is already a number
# Attribute Error in: 564 Column is already a number
# Attribute Error in: 565 Column is already a number
# Attribute Error in: 566 Column is already a number
# Attribute Error in: 567 Column is already a number
# Attribute Error in: 568 Column is already a number
# Attribute Error in: 569 Column is already a number
# Attribute Error in: 570 Column is already a number
# Attribute Error in: 571 Column is already a number
# Attribute Error in: 572 Column is already a number
# Attribute Error in: 573 Column is already a number
# Attribute Error in: 574 Column is already a number
# Attribute Error in: 575 Column is already a number
# Attribute Error in: 576 Column is already a number
# Attribute Error in: 577 Column is already a number
# Attribute Error in: 578 Column is already a number
# Attribute Error in: 579 Column is already a number
# Attribute Error in: 580 Column is already a number
# Attribute Error in: 581 Column is already a number
# Attribute Error in: 582 Column is already a number
# Attribute Error in: 583 Column is already a number
# Attribute Error in: 584 Column is already a number
# Attribute Error in: 585 Column is already a number
# Attribute Error in: 586 Column is already a number
# Attribute Error in: 587 Column is already a number
# Attribute Error in: 588 Column is already a number
# Attribute Error in: 589 Column is already a number
# Attribute Error in: 590 Column is already a number
# Attribute Error in: 591 Column is already a number
# Attribute Error in: 592 Column is already a number
# Attribute Error in: 593 Column is already a number
# Attribute Error in: 594 Column is already a number
# Attribute Error in: 595 Column is already a number
# Attribute Error in: 596 Column is already a number
# Attribute Error in: 597 Column is already a number
# Attribute Error in: 598 Column is already a number
# Attribute Error in: 599 Column is already a number
# Attribute Error in: 600 Column is already a number
# Attribute Error in: 601 Column is already a number
# Attribute Error in: 602 Column is already a number
# Attribute Error in: 603 Column is already a number
# Attribute Error in: 604 Column is already a number
# Attribute Error in: 605 Column is already a number
# Attribute Error in: 606 Column is already a number
# Attribute Error in: 607 Column is already a number
# Attribute Error in: 608 Column is already a number
# Attribute Error in: 609 Column is already a number
# Attribute Error in: 610 Column is already a number
# Attribute Error in: 611 Column is already a number
# Attribute Error in: 612 Column is already a number
# Attribute Error in: 613 Column is already a number
# Attribute Error in: 614 Column is already a number
# Attribute Error in: 615 Column is already a number
# Attribute Error in: 616 Column is already a number
# Attribute Error in: 617 Column is already a number
# Attribute Error in: 618 Column is already a number
# Attribute Error in: 619 Column is already a number
# Attribute Error in: 620 Column is already a number
# Attribute Error in: 621 Column is already a number
# Attribute Error in: 622 Column is already a number
# Attribute Error in: 623 Column is already a number
# Attribute Error in: 624 Column is already a number
# Attribute Error in: 625 Column is already a number
# Attribute Error in: 626 Column is already a number
# Attribute Error in: 627 Column is already a number
# Attribute Error in: 628 Column is already a number
# Attribute Error in: 629 Column is already a number
# Attribute Error in: 630 Column is already a number
# Attribute Error in: 631 Column is already a number
# Attribute Error in: 632 Column is already a number
# Attribute Error in: 633 Column is already a number
# Attribute Error in: 634 Column is already a number
# Attribute Error in: 635 Column is already a number
# Attribute Error in: 636 Column is already a number
# Attribute Error in: 637 Column is already a number
# Attribute Error in: 638 Column is already a number
# Attribute Error in: 639 Column is already a number
# Attribute Error in: 640 Column is already a number
# Attribute Error in: 641 Column is already a number
# Attribute Error in: 642 Column is already a number
# Attribute Error in: 643 Column is already a number
# Attribute Error in: 644 Column is already a number
# Attribute Error in: 645 Column is already a number
# Attribute Error in: 646 Column is already a number
# Attribute Error in: 647 Column is already a number
# Attribute Error in: 648 Column is already a number
# Attribute Error in: 649 Column is already a number
# Attribute Error in: 650 Column is already a number
# Attribute Error in: 651 Column is already a number
# Attribute Error in: 652 Column is already a number
# Attribute Error in: 653 Column is already a number
# Attribute Error in: 654 Column is already a number
# Attribute Error in: 655 Column is already a number
# Attribute Error in: 656 Column is already a number
# Attribute Error in: 657 Column is already a number
# Attribute Error in: 658 Column is already a number
# Attribute Error in: 659 Column is already a number
# Attribute Error in: 660 Column is already a number
# Attribute Error in: 661 Column is already a number
# Attribute Error in: 662 Column is already a number
# Attribute Error in: 663 Column is already a number
# Attribute Error in: 664 Column is already a number
# Attribute Error in: 665 Column is already a number
# Attribute Error in: 666 Column is already a number
# Attribute Error in: 667 Column is already a number
# Attribute Error in: 668 Column is already a number
# Attribute Error in: 669 Column is already a number
# Attribute Error in: 670 Column is already a number
# Attribute Error in: 671 Column is already a number
# Attribute Error in: 672 Column is already a number
# Attribute Error in: 673 Column is already a number
# Attribute Error in: 674 Column is already a number
# Attribute Error in: 675 Column is already a number
# Attribute Error in: 676 Column is already a number
# Attribute Error in: 677 Column is already a number
# Attribute Error in: 678 Column is already a number
# Attribute Error in: 679 Column is already a number
# Attribute Error in: 680 Column is already a number
# Attribute Error in: 681 Column is already a number
# Attribute Error in: 682 Column is already a number
# Attribute Error in: 683 Column is already a number
# Attribute Error in: 684 Column is already a number
# Attribute Error in: 685 Column is already a number
# Attribute Error in: 686 Column is already a number
# Attribute Error in: 687 Column is already a number
# Attribute Error in: 688 Column is already a number
# Attribute Error in: 689 Column is already a number
# Attribute Error in: 690 Column is already a number
# Attribute Error in: 691 Column is already a number
# Attribute Error in: 692 Column is already a number
# Attribute Error in: 693 Column is already a number
# Attribute Error in: 694 Column is already a number
# Attribute Error in: 695 Column is already a number
# Attribute Error in: 696 Column is already a number
# Attribute Error in: 697 Column is already a number
# Attribute Error in: 698 Column is already a number
# Attribute Error in: 699 Column is already a number
# Attribute Error in: 700 Column is already a number
# Attribute Error in: 701 Column is already a number
# Attribute Error in: 702 Column is already a number
# Attribute Error in: 703 Column is already a number
# Attribute Error in: 704 Column is already a number
# Attribute Error in: 705 Column is already a number
# Attribute Error in: 706 Column is already a number
# Attribute Error in: 707 Column is already a number
# Attribute Error in: 708 Column is already a number
# Attribute Error in: 709 Column is already a number
# Attribute Error in: 710 Column is already a number
# Attribute Error in: 711 Column is already a number
# Attribute Error in: 712 Column is already a number
# Attribute Error in: 713 Column is already a number
# Attribute Error in: 714 Column is already a number
# Attribute Error in: 715 Column is already a number
# Attribute Error in: 716 Column is already a number
# Attribute Error in: 717 Column is already a number
# Attribute Error in: 718 Column is already a number
# Attribute Error in: 719 Column is already a number
# Attribute Error in: 720 Column is already a number
# Attribute Error in: 721 Column is already a number
# Attribute Error in: 722 Column is already a number
# Attribute Error in: 723 Column is already a number
# Attribute Error in: 724 Column is already a number
# Attribute Error in: 725 Column is already a number
# Attribute Error in: 726 Column is already a number
# Attribute Error in: 727 Column is already a number
# Attribute Error in: 728 Column is already a number
# Attribute Error in: 729 Column is already a number
# Attribute Error in: 730 Column is already a number
# Attribute Error in: 731 Column is already a number
# Attribute Error in: 732 Column is already a number
# Attribute Error in: 733 Column is already a number
# Attribute Error in: 734 Column is already a number
# Attribute Error in: 735 Column is already a number
# Attribute Error in: 736 Column is already a number
# Attribute Error in: 737 Column is already a number
# Attribute Error in: 738 Column is already a number
# Attribute Error in: 739 Column is already a number
# Attribute Error in: 740 Column is already a number
# Attribute Error in: 741 Column is already a number
# Attribute Error in: 742 Column is already a number
# Attribute Error in: 743 Column is already a number
# Attribute Error in: 744 Column is already a number
# Attribute Error in: 745 Column is already a number
# Attribute Error in: 746 Column is already a number
# Attribute Error in: 747 Column is already a number
# Attribute Error in: 748 Column is already a number
# Attribute Error in: 749 Column is already a number
# Attribute Error in: 750 Column is already a number
# Attribute Error in: 751 Column is already a number
# Attribute Error in: 752 Column is already a number
# Attribute Error in: 753 Column is already a number
# Attribute Error in: 754 Column is already a number
# Attribute Error in: 755 Column is already a number
# Attribute Error in: 756 Column is already a number
# Attribute Error in: 757 Column is already a number
# Attribute Error in: 758 Column is already a number
# Attribute Error in: 759 Column is already a number
# Attribute Error in: 760 Column is already a number
# Attribute Error in: 761 Column is already a number
# Attribute Error in: 762 Column is already a number
# Attribute Error in: 763 Column is already a number
# Attribute Error in: 764 Column is already a number
# Attribute Error in: 765 Column is already a number
# Attribute Error in: 766 Column is already a number
# Attribute Error in: 767 Column is already a number
# Attribute Error in: 768 Column is already a number
# Attribute Error in: 769 Column is already a number
# Attribute Error in: 770 Column is already a number
# Attribute Error in: 771 Column is already a number
# Attribute Error in: 772 Column is already a number
# Attribute Error in: 773 Column is already a number
# Attribute Error in: 774 Column is already a number
# Attribute Error in: 775 Column is already a number
# Attribute Error in: 776 Column is already a number
# Attribute Error in: 777 Column is already a number
# Attribute Error in: 778 Column is already a number
# Attribute Error in: 779 Column is already a number
# Attribute Error in: 780 Column is already a number
# Attribute Error in: 781 Column is already a number
# Attribute Error in: 782 Column is already a number
# Attribute Error in: 783 Column is already a number
# Attribute Error in: 784 Column is already a number
# Attribute Error in: 785 Column is already a number
# Attribute Error in: 786 Column is already a number
# Attribute Error in: 787 Column is already a number
# Attribute Error in: 788 Column is already a number
# Attribute Error in: 789 Column is already a number
# Attribute Error in: 790 Column is already a number
# Attribute Error in: 791 Column is already a number
# Attribute Error in: 792 Column is already a number
# Attribute Error in: 793 Column is already a number
# Attribute Error in: 794 Column is already a number
# Attribute Error in: 795 Column is already a number
# Attribute Error in: 796 Column is already a number
# Attribute Error in: 797 Column is already a number
# Attribute Error in: 798 Column is already a number
# Attribute Error in: 799 Column is already a number
# Attribute Error in: 800 Column is already a number
# Attribute Error in: 801 Column is already a number
# Attribute Error in: 802 Column is already a number
# Attribute Error in: 803 Column is already a number
# Attribute Error in: 804 Column is already a number
# Attribute Error in: 805 Column is already a number
# Attribute Error in: 806 Column is already a number
# Attribute Error in: 807 Column is already a number
# Attribute Error in: 808 Column is already a number
# Attribute Error in: 809 Column is already a number
# Attribute Error in: 810 Column is already a number
# Attribute Error in: 811 Column is already a number
# Attribute Error in: 812 Column is already a number
# Attribute Error in: 813 Column is already a number
# Attribute Error in: 814 Column is already a number
# Attribute Error in: 815 Column is already a number
# Attribute Error in: 816 Column is already a number
# Attribute Error in: 817 Column is already a number
# Attribute Error in: 818 Column is already a number
# Attribute Error in: 819 Column is already a number
# Attribute Error in: 820 Column is already a number
# Attribute Error in: 821 Column is already a number
# Attribute Error in: 822 Column is already a number
# Attribute Error in: 823 Column is already a number
# Attribute Error in: 824 Column is already a number
# Attribute Error in: 825 Column is already a number
# Attribute Error in: 826 Column is already a number
# Attribute Error in: 827 Column is already a number
# Attribute Error in: 828 Column is already a number
# Attribute Error in: 829 Column is already a number
# Attribute Error in: 830 Column is already a number
# Attribute Error in: 831 Column is already a number
# Attribute Error in: 832 Column is already a number
# Attribute Error in: 833 Column is already a number
# Attribute Error in: 834 Column is already a number
# Attribute Error in: 835 Column is already a number
# Attribute Error in: 836 Column is already a number
# Attribute Error in: 837 Column is already a number
# Attribute Error in: 838 Column is already a number
# Attribute Error in: 839 Column is already a number
# Attribute Error in: 840 Column is already a number
# Attribute Error in: 841 Column is already a number
# Attribute Error in: 842 Column is already a number
# Attribute Error in: 843 Column is already a number
# Attribute Error in: 844 Column is already a number
# Attribute Error in: 845 Column is already a number
# Attribute Error in: 846 Column is already a number
# Attribute Error in: 847 Column is already a number
# Attribute Error in: 848 Column is already a number
# Attribute Error in: 849 Column is already a number
# Attribute Error in: 850 Column is already a number
# Attribute Error in: 851 Column is already a number
# Attribute Error in: 852 Column is already a number
# Attribute Error in: 853 Column is already a number
# Attribute Error in: 854 Column is already a number
# Attribute Error in: 855 Column is already a number
# Attribute Error in: 856 Column is already a number
# Attribute Error in: 857 Column is already a number
# Attribute Error in: 858 Column is already a number
# Attribute Error in: 859 Column is already a number
# Attribute Error in: 860 Column is already a number
# Attribute Error in: 861 Column is already a number
# Attribute Error in: 862 Column is already a number
# Attribute Error in: 863 Column is already a number
# Attribute Error in: 864 Column is already a number
# Attribute Error in: 865 Column is already a number
# Attribute Error in: 866 Column is already a number
# Attribute Error in: 867 Column is already a number
# Attribute Error in: 868 Column is already a number
# Attribute Error in: 869 Column is already a number
# Attribute Error in: 870 Column is already a number
# Attribute Error in: 871 Column is already a number
# Attribute Error in: 872 Column is already a number
# Attribute Error in: 873 Column is already a number
# Attribute Error in: 874 Column is already a number
# Attribute Error in: 875 Column is already a number
# Attribute Error in: 876 Column is already a number
# Attribute Error in: 877 Column is already a number
# Attribute Error in: 878 Column is already a number
# Attribute Error in: 879 Column is already a number
# Attribute Error in: 880 Column is already a number
# Attribute Error in: 881 Column is already a number
# Attribute Error in: 882 Column is already a number
# Attribute Error in: 883 Column is already a number
# Attribute Error in: 884 Column is already a number
# Attribute Error in: 885 Column is already a number
# Attribute Error in: 886 Column is already a number
# Attribute Error in: 887 Column is already a number
# Attribute Error in: 888 Column is already a number
# Attribute Error in: 889 Column is already a number
# Attribute Error in: 890 Column is already a number
# Attribute Error in: 891 Column is already a number
# Attribute Error in: 892 Column is already a number
# Attribute Error in: 893 Column is already a number
# Attribute Error in: 894 Column is already a number
# Attribute Error in: 895 Column is already a number
# Attribute Error in: 896 Column is already a number
# Attribute Error in: 897 Column is already a number
# Attribute Error in: 898 Column is already a number
# Attribute Error in: 899 Column is already a number
# Attribute Error in: 900 Column is already a number
# Attribute Error in: 901 Column is already a number
# Attribute Error in: 902 Column is already a number
# Attribute Error in: 903 Column is already a number
# Attribute Error in: 904 Column is already a number
# Attribute Error in: 905 Column is already a number
# Attribute Error in: 906 Column is already a number
# Attribute Error in: 907 Column is already a number
# Attribute Error in: 908 Column is already a number
# Attribute Error in: 909 Column is already a number
# Attribute Error in: 910 Column is already a number
# Attribute Error in: 911 Column is already a number
# Attribute Error in: 912 Column is already a number
# Attribute Error in: 913 Column is already a number
# Attribute Error in: 914 Column is already a number
# Attribute Error in: 915 Column is already a number
# Attribute Error in: 916 Column is already a number
# Attribute Error in: 917 Column is already a number
# Attribute Error in: 918 Column is already a number
# Attribute Error in: 919 Column is already a number
# Attribute Error in: 920 Column is already a number
# Attribute Error in: 921 Column is already a number
# Attribute Error in: 922 Column is already a number
# Attribute Error in: 923 Column is already a number
# Attribute Error in: 924 Column is already a number
# Attribute Error in: 925 Column is already a number
# Attribute Error in: 926 Column is already a number
# Attribute Error in: 927 Column is already a number
# Attribute Error in: 928 Column is already a number
# Attribute Error in: 929 Column is already a number
# Attribute Error in: 930 Column is already a number
# Attribute Error in: 931 Column is already a number
# Attribute Error in: 932 Column is already a number
# Attribute Error in: 933 Column is already a number
# Attribute Error in: 934 Column is already a number
# Attribute Error in: 935 Column is already a number
# Attribute Error in: 936 Column is already a number
# Attribute Error in: 937 Column is already a number
# Attribute Error in: 938 Column is already a number
# Attribute Error in: 939 Column is already a number
# ...
# Attribute Error in: 55 Column is already a number
# Attribute Error in: 56 Column is already a number
# Attribute Error in: 57 Column is already a number
# Attribute Error in: 58 Column is already a number
# Attribute Error in: 59 Column is already a number
# Attribute Error in: 60 Column is already a number
# Attribute Error in: 61 Column is already a number
# Attribute Error in: 62 Column is already a number
# Attribute Error in: 63 Column is already a number
# Attribute Error in: 64 Column is already a number
# Attribute Error in: 65 Column is already a number
# Attribute Error in: 66 Column is already a number
# Attribute Error in: 67 Column is already a number
# Attribute Error in: 68 Column is already a number
# Attribute Error in: 69 Column is already a number
# Attribute Error in: 70 Column is already a number
# Attribute Error in: 71 Column is already a number
# Attribute Error in: 72 Column is already a number
# Attribute Error in: 73 Column is already a number
# Attribute Error in: 74 Column is already a number
# Attribute Error in: 75 Column is already a number
# Attribute Error in: 76 Column is already a number
# Attribute Error in: 77 Column is already a number
# Attribute Error in: 78 Column is already a number
# Attribute Error in: 79 Column is already a number
# Attribute Error in: 80 Column is already a number
# Attribute Error in: 81 Column is already a number
# Attribute Error in: 82 Column is already a number
# Attribute Error in: 83 Column is already a number
# Attribute Error in: 84 Column is already a number
# Attribute Error in: 85 Column is already a number
# Attribute Error in: 86 Column is already a number
# Attribute Error in: 87 Column is already a number
# Attribute Error in: 88 Column is already a number
# Attribute Error in: 89 Column is already a number
# Attribute Error in: 90 Column is already a number
# Attribute Error in: 91 Column is already a number
# Attribute Error in: 92 Column is already a number
# Attribute Error in: 93 Column is already a number
# Attribute Error in: 94 Column is already a number
# Attribute Error in: 95 Column is already a number
# Attribute Error in: 96 Column is already a number
# Attribute Error in: 97 Column is already a number
# Attribute Error in: 98 Column is already a number
# Attribute Error in: 99 Column is already a number
# Attribute Error in: 100 Column is already a number
# Attribute Error in: 101 Column is already a number
# Attribute Error in: 102 Column is already a number
# Attribute Error in: 103 Column is already a number
# Attribute Error in: 104 Column is already a number
# Attribute Error in: 105 Column is already a number
# Attribute Error in: 106 Column is already a number
# Attribute Error in: 107 Column is already a number
# Attribute Error in: 108 Column is already a number
# Attribute Error in: 109 Column is already a number
# Attribute Error in: 110 Column is already a number
# Attribute Error in: 111 Column is already a number
# Attribute Error in: 112 Column is already a number
# Attribute Error in: 113 Column is already a number
# Attribute Error in: 114 Column is already a number
# Attribute Error in: 115 Column is already a number
# Attribute Error in: 116 Column is already a number
# Attribute Error in: 117 Column is already a number
# Attribute Error in: 118 Column is already a number
# Attribute Error in: 119 Column is already a number
# Attribute Error in: 120 Column is already a number
# Attribute Error in: 121 Column is already a number
# Attribute Error in: 122 Column is already a number
# Attribute Error in: 123 Column is already a number
# Attribute Error in: 124 Column is already a number
# Attribute Error in: 125 Column is already a number
# Attribute Error in: 126 Column is already a number
# Attribute Error in: 127 Column is already a number
# Attribute Error in: 128 Column is already a number
# Attribute Error in: 129 Column is already a number
# Attribute Error in: 130 Column is already a number
# Attribute Error in: 131 Column is already a number
# Attribute Error in: 132 Column is already a number
# Attribute Error in: 133 Column is already a number
# Attribute Error in: 134 Column is already a number
# Attribute Error in: 135 Column is already a number
# Attribute Error in: 136 Column is already a number
# Attribute Error in: 137 Column is already a number
# Attribute Error in: 138 Column is already a number
# Attribute Error in: 139 Column is already a number
# Attribute Error in: 140 Column is already a number
# Attribute Error in: 141 Column is already a number
# Attribute Error in: 142 Column is already a number
# Attribute Error in: 143 Column is already a number
# Attribute Error in: 144 Column is already a number
# Attribute Error in: 145 Column is already a number
# Attribute Error in: 146 Column is already a number
# Attribute Error in: 147 Column is already a number
# Attribute Error in: 148 Column is already a number
# Attribute Error in: 149 Column is already a number
# Attribute Error in: 150 Column is already a number
# Attribute Error in: 151 Column is already a number
# Attribute Error in: 152 Column is already a number
# Attribute Error in: 153 Column is already a number
# Attribute Error in: 154 Column is already a number
# Attribute Error in: 155 Column is already a number
# Attribute Error in: 156 Column is already a number
# Attribute Error in: 157 Column is already a number
# Attribute Error in: 158 Column is already a number
# Attribute Error in: 159 Column is already a number
# Attribute Error in: 160 Column is already a number
# Attribute Error in: 161 Column is already a number
# Attribute Error in: 162 Column is already a number
# Attribute Error in: 163 Column is already a number
# Attribute Error in: 164 Column is already a number
# Attribute Error in: 165 Column is already a number
# Attribute Error in: 166 Column is already a number
# Attribute Error in: 167 Column is already a number
# Attribute Error in: 168 Column is already a number
# Attribute Error in: 169 Column is already a number
# Attribute Error in: 170 Column is already a number
# Attribute Error in: 171 Column is already a number
# Attribute Error in: 172 Column is already a number
# Attribute Error in: 173 Column is already a number
# Attribute Error in: 174 Column is already a number
# Attribute Error in: 175 Column is already a number
# Attribute Error in: 176 Column is already a number
# Attribute Error in: 177 Column is already a number
# Attribute Error in: 178 Column is already a number
# Attribute Error in: 179 Column is already a number
# Attribute Error in: 180 Column is already a number
# Attribute Error in: 181 Column is already a number
# Attribute Error in: 182 Column is already a number
# Attribute Error in: 183 Column is already a number
# Attribute Error in: 184 Column is already a number
# Attribute Error in: 185 Column is already a number
# Attribute Error in: 186 Column is already a number
# Attribute Error in: 187 Column is already a number
# Attribute Error in: 188 Column is already a number
# Attribute Error in: 189 Column is already a number
# Attribute Error in: 190 Column is already a number
# Attribute Error in: 191 Column is already a number
# Attribute Error in: 192 Column is already a number
# Attribute Error in: 193 Column is already a number
# Attribute Error in: 194 Column is already a number
# Attribute Error in: 195 Column is already a number
# Attribute Error in: 196 Column is already a number
# Attribute Error in: 197 Column is already a number
# Attribute Error in: 198 Column is already a number
# Attribute Error in: 199 Column is already a number
# Attribute Error in: 200 Column is already a number
# Attribute Error in: 201 Column is already a number
# Attribute Error in: 202 Column is already a number
# Attribute Error in: 203 Column is already a number
# Attribute Error in: 204 Column is already a number
# Attribute Error in: 205 Column is already a number
# Attribute Error in: 206 Column is already a number
# Attribute Error in: 207 Column is already a number
# Attribute Error in: 208 Column is already a number
# Attribute Error in: 209 Column is already a number
# Attribute Error in: 210 Column is already a number
# Attribute Error in: 211 Column is already a number
# Attribute Error in: 212 Column is already a number
# Attribute Error in: 213 Column is already a number
# Attribute Error in: 214 Column is already a number
# Attribute Error in: 215 Column is already a number
# Attribute Error in: 216 Column is already a number
# Attribute Error in: 217 Column is already a number
# Attribute Error in: 218 Column is already a number
# Attribute Error in: 219 Column is already a number
# Attribute Error in: 220 Column is already a number
# Attribute Error in: 221 Column is already a number
# Attribute Error in: 222 Column is already a number
# Attribute Error in: 223 Column is already a number
# Attribute Error in: 224 Column is already a number
# Attribute Error in: 225 Column is already a number
# Attribute Error in: 226 Column is already a number
# Attribute Error in: 227 Column is already a number
# Attribute Error in: 228 Column is already a number
# Attribute Error in: 229 Column is already a number
# Attribute Error in: 230 Column is already a number
# Attribute Error in: 231 Column is already a number
# Attribute Error in: 232 Column is already a number
# Attribute Error in: 233 Column is already a number
# Attribute Error in: 234 Column is already a number
# Attribute Error in: 235 Column is already a number
# Attribute Error in: 236 Column is already a number
# Attribute Error in: 237 Column is already a number
# Attribute Error in: 238 Column is already a number
# Attribute Error in: 239 Column is already a number
# Attribute Error in: 240 Column is already a number
# Attribute Error in: 241 Column is already a number
# Attribute Error in: 242 Column is already a number
# Attribute Error in: 243 Column is already a number
# Attribute Error in: 244 Column is already a number
# Attribute Error in: 245 Column is already a number
# Attribute Error in: 246 Column is already a number
# Attribute Error in: 247 Column is already a number
# Attribute Error in: 248 Column is already a number
# Attribute Error in: 249 Column is already a number
# Attribute Error in: 250 Column is already a number
# Attribute Error in: 251 Column is already a number
# Attribute Error in: 252 Column is already a number
# Attribute Error in: 253 Column is already a number
# Attribute Error in: 254 Column is already a number
# Attribute Error in: 255 Column is already a number
# Attribute Error in: 256 Column is already a number
# Attribute Error in: 257 Column is already a number
# Attribute Error in: 258 Column is already a number
# Attribute Error in: 259 Column is already a number
# Attribute Error in: 260 Column is already a number
# Attribute Error in: 261 Column is already a number
# Attribute Error in: 262 Column is already a number
# Attribute Error in: 263 Column is already a number
# Attribute Error in: 264 Column is already a number
# Attribute Error in: 265 Column is already a number
# Attribute Error in: 266 Column is already a number
# Attribute Error in: 267 Column is already a number
# Attribute Error in: 268 Column is already a number
# Attribute Error in: 269 Column is already a number
# Attribute Error in: 270 Column is already a number
# Attribute Error in: 271 Column is already a number
# Attribute Error in: 272 Column is already a number
# Attribute Error in: 273 Column is already a number
# Attribute Error in: 274 Column is already a number
# Attribute Error in: 275 Column is already a number
# Attribute Error in: 276 Column is already a number
# Attribute Error in: 277 Column is already a number
# Attribute Error in: 278 Column is already a number
# Attribute Error in: 279 Column is already a number
# Attribute Error in: 280 Column is already a number
# Attribute Error in: 281 Column is already a number
# Attribute Error in: 282 Column is already a number
# Attribute Error in: 283 Column is already a number
# Attribute Error in: 284 Column is already a number
# Attribute Error in: 285 Column is already a number
# Attribute Error in: 286 Column is already a number
# Attribute Error in: 287 Column is already a number
# Attribute Error in: 288 Column is already a number
# Attribute Error in: 289 Column is already a number
# Attribute Error in: 290 Column is already a number
# Attribute Error in: 291 Column is already a number
# Attribute Error in: 292 Column is already a number
# Attribute Error in: 293 Column is already a number
# Attribute Error in: 294 Column is already a number
# Attribute Error in: 295 Column is already a number
# Attribute Error in: 296 Column is already a number
# 5380 - ende 7424 normale version reichen study reports.csv
# first 100 study reports.csv
# short version study reports.csv
# short version study reports_copy.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[81], line 4
#       2 print(file)
#       3 url = base_url + file
# ----> 4 df = pd.read_csv(url, sep=";")
#       5 correct_right_shift(df)
#       6 add_budget_and_finance_column(df)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data_original/short version study reports_copy.csv'

# %% [markdown]
# #### Merging all sub-datasets together

# %%
files = []
for file in os.listdir(dest_url):
    if file.endswith(".csv"):
        files.append(file)

df = pd.DataFrame()
for file in files:
    df_help = pd.read_csv(dest_url + file, sep=";")
    df = pd.concat([df, df_help])

df.to_csv(dest_url + "final.csv", index=False, sep=";")
