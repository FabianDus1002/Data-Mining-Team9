# %%
# !pip install xlsxwriter
# Out:
# ...
#   Using cached XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Using cached XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv(r"./data/final.csv", sep=";")

# %%
df.head()
# Out:
#   Land der Gastinstitution                                  Gastinstitution  \
# 0                 Portugal             PTLISBOA109 - Universidade de Lisboa
# 1                 Südkorea  KRDAEGU01 - Kyungpook National University (KNU)
# 2                 Südkorea  KRDAEGU01 - Kyungpook National University (KNU)
# 3                 Südkorea  KRDAEGU01 - Kyungpook National University (KNU)
# 4                      USA              USGAINESV01 - University of Florida
#
#   Studienjahr                                          Fakultaet  \
# 0   2022/2023  Fakultät für Wirtschaftsinformatik und Wirtsch...
# 1   2022/2023  Fakultät für Wirtschaftsinformatik und Wirtsch...
# 2   2022/2023  Fakultät für Wirtschaftsinformatik und Wirtsch...
# 3   2022/2023  Fakultät für Wirtschaftsinformatik und Wirtsch...
# 4   2022/2023  Fakultät für Wirtschaftsinformatik und Wirtsch...
#
#                                          Studiengang Verfasser-ID  \
# ...

# %%
i = 0
for col in df.columns:
    print (str(i) + ": " + col)
    i +=1
# Out:
# 0: Land der Gastinstitution
# 1: Gastinstitution
# 2: Studienjahr
# 3: Fakultaet
# 4: Studiengang
# 5: Verfasser-ID
# 6: Vorbereitung
# 7: Vorbereitung_Label
# 8: Vorbereitung_Comment
# 9: Unterkunft
# 10: Unterkunft_Label
# 11: Unterkunft_Comment
# 12: Studium
# 13: Studium_Label
# 14: Studium_Comment
# 15: Freizeit
# 16: Freizeit_Label
# 17: Freizeit_Comment
# 18: Budget
# 19: Budget_Label
# 20: Budget_Comment
# 21: Finanzierung
# 22: Finanzierung_Label
# 23: Finanzierung_Comment
# 24: Kurswahl
# 25: Kurswahl_Label
# 26: Kurswahl_Comment
# 27: Fazit
# 28: Fazit_Label
# 29: Fazit_Comment
# 30: url
# 31: downloaded

# %%
df.insert(29, "Fazit_Comment", "")

# %%
df = df.drop('Unterkunft_Label', axis=1)

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#   Land der Gastinstitution                                    Gastinstitution  \
# 0                   Kanada                  CAKINGSTON01 - Queen`s University
# 1                   Ungarn    HUBUDAPES12 - Peter Pazmany Catholic University
# 2               Frankreich             FRSTRASBO48 - Université de Strasbourg
# 3                 Südkorea                      KRSEOUL09 - Yonsei University
# 4     China, Volksrepublik  CNHONGKON05 - City University of Hong Kong (Ci...
#
#   Studienjahr                                    Fakultaet  \
# 0   2019/2020  Fakultät für Betriebswirtschaftslehre - BWL
# 1   2016/2017          Abteilung Rechtswissenschaft - JURA
# 2   2022/2023  Fakultät für Betriebswirtschaftslehre - BWL
# 3   2020/2021  Fakultät für Betriebswirtschaftslehre - BWL
# 4   2022/2023     Fakultät für Sozialwissenschaften - SOWI
#
#                                       Studiengang               Verfasser-ID  \
# ...

# %%
df.to_csv("randomized_labeled_final.csv", sep=";")

# %%
df.to_excel("randomized_label_final.xlsx", engine='xlsxwriter')
