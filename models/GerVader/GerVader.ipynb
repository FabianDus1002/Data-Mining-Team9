# %% [markdown]
# # GerVader

# %% [markdown]
# We used the repository https://github.com/KarstenAMF/GerVADER to generate the CSVs containing the postive, negative and neutral lagbeled texts.

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, classification_report
import matplotlib.pyplot as plt

# %%
#path to the labeled Data of the Semester Abroad Reviews and to the three GerVader Files
path_labeledData = "../data/subset_german_studium.csv"
path_neg = "../data/GERVADER__negative.csv"
path_pos = "../data/GERVADER_positive.csv"
path_neu = "../data/GERVADER__neutral.csv"

# %%
# Column names
column_names_labeledData = ['ID', 'Studium', 'Studium_Label', 'Studium_Comment']
column_names_GerVader = ['Studium', 'ID', 'Sentiment_GerVader', 'Sentiment_Detail_GreVader']

# Read Labeled Data
df_StudiumGerman = pd.read_csv(path_labeledData, sep=';',names=column_names_labeledData, encoding="latin1", skiprows=1, dtype={'ID': int}, )
df_StudiumGerman.dropna(subset=['Studium_Label'], inplace=True)

# %%
# Read GerVader Data
vader_neg = pd.read_csv(path_neg, sep=';', names=column_names_GerVader, encoding = 'utf-8', keep_default_na=False, dtype={'ID': int})
vader_neg['GerVader_Label'] = 'negative'
vader_neg.head()
# Out:
#                                              Studium   ID  Sentiment_GerVader  \
# 0  Ich habe mein Auslandssemester frühzeitig abbr...   15             -0.2500
# 1  Das HWS geht an der UniStra von Anfang Septemb...   38             -0.4522
# 2  Da ich kein B2 französisch Zertifikat hatte, h...   76             -0.6997
# 3  Meine Kurse fanden alle in der Facultad de Fil...  119             -0.1987
# 4  Das Studium an der KUFS ist anstrengend, zumin...  143             -0.5551
#
#                            Sentiment_Detail_GreVader GerVader_Label
# 0  {'neg': 0.25, 'neu': 0.75, 'pos': 0.0, 'compou...       negative
# 1  {'neg': 0.077, 'neu': 0.874, 'pos': 0.049, 'co...       negative
# 2  {'neg': 0.079, 'neu': 0.894, 'pos': 0.026, 'co...       negative
# 3  {'neg': 0.057, 'neu': 0.893, 'pos': 0.05, 'com...       negative
# 4  {'neg': 0.077, 'neu': 0.864, 'pos': 0.059, 'co...       negative

# %%
vader_pos = pd.read_csv(path_pos, sep=';', names=column_names_GerVader, encoding = 'UTF-8', dtype={'ID': int})
vader_pos['GerVader_Label'] = 'positive'
vader_pos.head()
# Out:
#                                              Studium  ID  Sentiment_GerVader  \
# 0  Die Vorlesungszeit war von Anfang September bi...   0            979.0000
# 1  Die Pazmany Universität ist sehr klein im Verg...   1              0.9907
# 2  Da die Vorlesungen wegen der Pandemie online s...   3              0.9868
# 3  Die City University of Hong Kong hat eine groß...   4              0.8225
# 4  Das Studium an der NUS hat mir großen Spaß gem...   6              0.9823
#
#                            Sentiment_Detail_GreVader GerVader_Label
# 0  {'neg': 0.016, 'neu': 0.844, 'pos': 0.14, 'com...       positive
# 1  {'neg': 0.027, 'neu': 0.756, 'pos': 0.218, 'co...       positive
# 2  {'neg': 0.014, 'neu': 0.86, 'pos': 0.126, 'com...       positive
# 3  {'neg': 0.046, 'neu': 0.863, 'pos': 0.092, 'co...       positive
# 4  {'neg': 0.032, 'neu': 0.819, 'pos': 0.148, 'co...       positive

# %%
vader_neu = pd.read_csv(path_neu, sep=';', names=column_names_GerVader, encoding = 'UTF-8', skiprows=1, dtype={'ID': int})
vader_neu['GerVader_Label'] = 'neutral'
print(vader_neu['ID'].dtype)
vader_neu
# Out:
# int32
#                                               Studium   ID  \
# 0   Mit der Universität selbst hatten wir wenig zu...    2
# 1   Das Semester ist in kleinere Abschnitte untert...    5
# 2   Das Studium an der Universität hat mir leider ...   55
# 3   Im Gegensatz zu Mannheim, gibt es an der NHH k...   56
# 4   Im Gegensatz zur Uni Mannheim muss man an amer...   83
# 5   Nicht viel anders als Mannheim bis auf: Mehr a...   88
# 6   Meine Kurse fanden alle am Campus in Leioa sta...  129
# 7   Die Uni bietet viele Kursen für Austauschstude...  136
# 8   Das GSOM-Studium unterscheidet sich merklich v...  153
# 9   Die Kurswahl fand am 5. Juli statt. Die Regist...  161
# 10  Vom Aufbau der Vorlesung ist das Studium in Os...  197
# 11  Das Studium an der USC läuft deutlich anders a...  296
# 12  Die ESEADE ist eine kleine private Universität...  303
# 13  Die Vorlesungszeiten sind gleich der Zeiten in...  312
# 14  Dazu kann ich nicht so viel sagen, da ich dies...  320
# 15  Das Studium an der ESSEC ist anders als an der...  343
# 16  Ich entschied mich, alle Kurse auf Spanisch zu...  358
# 17  Die Kurswahl hat sich sehr schwierig gestaltet...  385
# 18  Ich muss zugeben das Niveau war viel niedriege...  393
# 19  Das Studium an der SDSU ist definitiv anders a...  421
# 20  Das Studium an der Université Nice Sophia Anti...  427
# 21  Das Studium in Frankreich war anders als in Ma...  439
# 22  Der Unterschied von einer schwedischen zu eine...  443
# 23  Das Studium ist wie auch das Leben in Frankrei...  459
# 24  Zum Anfang des Semesters hat man 2 Wochen Orie...  497
# 25  Das Kursangebot in Ferrara ist an sich relativ...  540
# 26  Das Studium an der AUT unterscheidet sich doch...  567
# 27  Die Kurse sind jeweils 3h lang, was für viele ...  575
# 28  Das Studium an der UofW ist gänzlich anders st...  593
# 29  Der Einschreibungsprozess an der UMASS war im ...  628
# 30  Das Niveau der Lehre an der Universität befand...  634
# 31  Da die Juristische Fakultät an der Uni TRE vie...  689
# 32  Da ich Englisch und Politikwissenschaften auf ...  725
# 33  Das Studienangebot für Medien- und Kommunikati...  729
# 34  Ein Studienjahr an UNCG ist in zwei Semester a...  736
# 35  Das Studium and der SDSU ist sehr viel einfach...  842
#
#     Sentiment_GerVader                          Sentiment_Detail_GreVader  \
# 0               0.5282  {'neg': 0.039, 'neu': 0.912, 'pos': 0.05, 'com...
# 1               0.1027  {'neg': 0.071, 'neu': 0.873, 'pos': 0.057, 'co...
# 2               0.5095  {'neg': 0.035, 'neu': 0.888, 'pos': 0.077, 'co...
# 3               0.1724  {'neg': 0.05, 'neu': 0.894, 'pos': 0.056, 'com...
# 4              -0.0475  {'neg': 0.055, 'neu': 0.9, 'pos': 0.044, 'comp...
# 5               0.1342  {'neg': 0.031, 'neu': 0.933, 'pos': 0.035, 'co...
# 6               0.4215  {'neg': 0.048, 'neu': 0.88, 'pos': 0.071, 'com...
# 7               0.1531  {'neg': 0.03, 'neu': 0.921, 'pos': 0.049, 'com...
# 8               0.1801  {'neg': 0.041, 'neu': 0.912, 'pos': 0.047, 'co...
# 9               0.5095  {'neg': 0.038, 'neu': 0.899, 'pos': 0.063, 'co...
# 10              0.5466  {'neg': 0.048, 'neu': 0.885, 'pos': 0.066, 'co...
# 11              0.4415  {'neg': 0.048, 'neu': 0.892, 'pos': 0.06, 'com...
# 12              0.4557  {'neg': 0.056, 'neu': 0.883, 'pos': 0.061, 'co...
# 13              0.5703  {'neg': 0.052, 'neu': 0.873, 'pos': 0.075, 'co...
# 14              0.5753  {'neg': 0.067, 'neu': 0.855, 'pos': 0.078, 'co...
# 15             -0.0103  {'neg': 0.059, 'neu': 0.899, 'pos': 0.043, 'co...
# 16              0.4788  {'neg': 0.054, 'neu': 0.891, 'pos': 0.055, 'co...
# 17              0.5267  {'neg': 0.081, 'neu': 0.832, 'pos': 0.087, 'co...
# 18              0.5994  {'neg': 0.045, 'neu': 0.819, 'pos': 0.136, 'co...
# 19              0.4228  {'neg': 0.013, 'neu': 0.947, 'pos': 0.041, 'co...
# 20              0.5859  {'neg': 0.0, 'neu': 0.954, 'pos': 0.046, 'comp...
# 21              0.4404  {'neg': 0.054, 'neu': 0.867, 'pos': 0.078, 'co...
# 22              0.5937  {'neg': 0.035, 'neu': 0.912, 'pos': 0.054, 'co...
# 23              0.4172  {'neg': 0.011, 'neu': 0.959, 'pos': 0.031, 'co...
# 24              0.4767  {'neg': 0.0, 'neu': 0.97, 'pos': 0.03, 'compou...
# 25              0.4136  {'neg': 0.082, 'neu': 0.823, 'pos': 0.095, 'co...
# 26              0.5562  {'neg': 0.025, 'neu': 0.921, 'pos': 0.053, 'co...
# 27              0.5574  {'neg': 0.159, 'neu': 0.573, 'pos': 0.268, 'co...
# 28              0.3744  {'neg': 0.024, 'neu': 0.927, 'pos': 0.049, 'co...
# 29              0.1548  {'neg': 0.051, 'neu': 0.885, 'pos': 0.064, 'co...
# 30              0.0982  {'neg': 0.046, 'neu': 0.904, 'pos': 0.05, 'com...
# 31              0.3114  {'neg': 0.09, 'neu': 0.818, 'pos': 0.092, 'com...
# 32              0.5606  {'neg': 0.0, 'neu': 0.932, 'pos': 0.068, 'comp...
# 33            583.0000  {'neg': 0.046, 'neu': 0.878, 'pos': 0.076, 'co...
# 34              0.0881  {'neg': 0.062, 'neu': 0.883, 'pos': 0.055, 'co...
# 35              0.3566  {'neg': 0.044, 'neu': 0.89, 'pos': 0.066, 'com...
#
#    GerVader_Label
# 0         neutral
# 1         neutral
# 2         neutral
# 3         neutral
# 4         neutral
# 5         neutral
# 6         neutral
# 7         neutral
# 8         neutral
# 9         neutral
# 10        neutral
# 11        neutral
# 12        neutral
# 13        neutral
# 14        neutral
# 15        neutral
# 16        neutral
# 17        neutral
# 18        neutral
# 19        neutral
# 20        neutral
# 21        neutral
# 22        neutral
# 23        neutral
# 24        neutral
# 25        neutral
# 26        neutral
# 27        neutral
# 28        neutral
# 29        neutral
# 30        neutral
# 31        neutral
# 32        neutral
# 33        neutral
# 34        neutral
# 35        neutral

# %% [markdown]
# ## GerVader Evaluation

# %%
#Joining the data of our labels with the labels of GerVader for evaluation of the results

df_gerVader = pd.concat([vader_neu, vader_pos, vader_neg])

# Skip or remove the row with the header
df_gerVader = df_gerVader[df_gerVader['ID'] != 'ID']

# Convert the 'ID' column from string to integer format
df_gerVader['ID'] = df_gerVader['ID'].astype(int)

joined_df = pd.merge(df_StudiumGerman, df_gerVader, on='ID', how='inner')
#joined_df

# %%
def calculateMatch(df):
    match_count = (df['Studium_Label'] == df['GerVader_Label']).sum()
    return match_count
    
calculateMatch(joined_df)

confusion_mat = confusion_matrix(joined_df['Studium_Label'], joined_df['GerVader_Label'], labels=['positive', 'negative', 'neutral'])

disp = ConfusionMatrixDisplay(confusion_matrix=confusion_mat, display_labels=['positive', 'negative', 'neutral'])
disp.plot()
plt.show()
print(f1_score(joined_df['Studium_Label'], joined_df['GerVader_Label'], labels=['positive', 'negative', 'neutral'], average='micro'))
print(classification_report(
    joined_df['Studium_Label'],
    joined_df['GerVader_Label'],
    output_dict=False,
    target_names=['positive', 'negative', 'neutral']
))
# Out:
# 0.50920245398773
#               precision    recall  f1-score   support
#
#     positive       0.30      0.19      0.23        16
#     negative       0.44      0.06      0.10        70
#      neutral       0.53      0.99      0.69        77
#
#     accuracy                           0.51       163
#    macro avg       0.42      0.41      0.34       163
# weighted avg       0.47      0.51      0.39       163
